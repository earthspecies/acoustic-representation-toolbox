# %% [markdown]
# # Spectral Hyperresolution Representation

# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import librosa
import librosa.display

# %%
path_name = '/home/peterbermant/.fastai/data/orchive-dataset.tar/call-catalog-xsilence/N01/A36-N01-062802-D004-12218.aiff'
signal_orca, sr_orca = sf.read(path_name)
time_orca = np.linspace(0,len(signal_orca)/sr_orca,len(signal_orca))
T_orca = 1 / sr_orca

# %%
from spectral_hyperresolution.linear_reassignment import high_resolution_spectrogram
data_2 = signal_orca.reshape(signal_orca.shape[0], 1)

q = 2
tdeci = 225
over = 20
noct = 24
minf = 4e-3
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import torch
from spectral_hyperresolution.linear_reassignment_pytorch import high_resolution_spectrogram

# %%
# %%time
q = 2
tdeci = 225
over = 20
noct = 24
minf = 4e-3 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 1min 16s, sys: 3.22 s, total: 1min 19s
# Wall time: 1min 21s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# %%time
q = 8
tdeci = 225
over = 40
noct = 24
minf = 4e-2 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 1min 18s, sys: 2 s, total: 1min 20s
# Wall time: 1min 20s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# %%time
q = 8
tdeci = 100
over = 40
noct = 24
minf = 4e-2 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 1min 19s, sys: 3.22 s, total: 1min 22s
# Wall time: 1min 22s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# %%time
q = 8
tdeci = 10
over = 40
noct = 24
minf = 4e-2 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 1min 18s, sys: 3.96 s, total: 1min 22s
# Wall time: 1min 22s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# %%time
q = 8
tdeci = 10
over = 40
noct = 48
minf = 4e-2 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 2min 38s, sys: 80 ms, total: 2min 38s
# Wall time: 2min 38s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# %%time
q = 8
tdeci = 8
over = 40
noct = 96
minf = 4e-2 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 5min 14s, sys: 124 ms, total: 5min 14s
# Wall time: 5min 15s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.gca().invert_yaxis()
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# %%time
q = 8
tdeci = 4
over = 80
noct = 96
minf = 4e-2 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 10min 41s, sys: 252 ms, total: 10min 41s
# Wall time: 10min 42s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.gca().invert_yaxis()
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# %%time
q = 8
tdeci = 4
over = 80
noct = 96
minf = 4e-3 # 4e-3 corresponds to frequency 4e-3 * sr which is 768 hz
maxf = 0.45
spectrogram = high_resolution_spectrogram(data_2, q, tdeci, over, noct, minf, maxf)
# Out:
# CPU times: user 20min 33s, sys: 592 ms, total: 20min 33s
# Wall time: 20min 35s

# %%
fig = plt.figure(figsize = (15,10))
librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
plt.gca().invert_yaxis()
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-31-9ed4622f828d> in <module>
#       1 fig = plt.figure(figsize = (15,10))
# ----> 2 librosa.display.specshow(librosa.core.amplitude_to_db(spectrogram.T), cmap='nipy_spectral')
#       3 plt.gca().invert_yaxis()
#       4 plt.xticks([])
#       5 plt.yticks([])
#
# ~/.pyenv/versions/3.6.7/envs/venv/lib/python3.6/site-packages/librosa/display.py in specshow(data, x_coords, y_coords, x_axis, y_axis, sr, hop_length, fmin, fmax, tuning, bins_per_octave, ax, **kwargs)
#     745
#     746     axes = __check_axes(ax)
# --> 747     out = axes.pcolormesh(x_coords, y_coords, data, **kwargs)
#     748     __set_current_image(ax, out)
#     749
#
# ~/.pyenv/versions/3.6.7/envs/venv/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.pyenv/versions/3.6.7/envs/venv/lib/python3.6/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6102         # convert to one dimensional arrays
#    6103         C = C.ravel()
# -> 6104         coords = np.column_stack((X, Y)).astype(float, copy=False)
#    6105         collection = mcoll.QuadMesh(Nx - 1, Ny - 1, coords,
#    6106                                     antialiased=antialiased, shading=shading,
#
# MemoryError: Unable to allocate 150. MiB for an array with shape (9798498, 2) and data type float64
